# %% [markdown]
# # Importing and using Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot()
plt.show()

# %%
plt.plot([1,2,3,4])

# %%
plt.plot([1,2,3,4]);

# %%
x = [1,2,3,4]
y = [11,22,33,44]
plt.plot(x,y);

# %%
x = [1,2,3,4]
y = [11,22,33,44]
plt.ylabel('Quantity of Milk used in Litres')
plt.xlabel('No. of weeks')

plt.plot(x,y);

# %%
# 1st method
fig = plt.figure()  # create a figure
ax = fig.add_subplot() # adds some axes
plt.show()

# %%
## 2nd method
fig = plt.figure() ## create a figure
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y)
plt.show()

# %%
# 3rd method (recommended)
fig, ax = plt.subplots()
ax.plot(x,y);  # add some data

# %%
fig, ax = plt.subplots()
ax.plot(x,[50,60,75,80]);  # add some data

# %% [markdown]
# ### Anatomy of a Matplotlib plot

# %%
fig, ax = plt.subplots()
ax.plot(x,[50,60,75,80]);  # add some data
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %% [markdown]
# ### Matplotlib example workflow

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
x = [1, 2, 3, 4]
y = [12, 24, 36, 48]
fig, ax = plt.subplots(figsize = (10, 10)) #( width, height)
ax.plot(x,y)
ax.set(title = 'Simple Plot',xlabel = 'x-axis', ylabel = 'y-axis')
#fig.save('../images/sample-plot,png')
# Out:
# [Text(0.5, 1.0, 'Simple Plot'), Text(0.5, 0, 'x-axis'), Text(0, 0.5, 'y-axis')]

# %%
x = [1,2,3,4]
y = [11,22,33,44]
plt.plot(x,y);
plt.ylabel('Quantity of Milk used in Litres')
plt.xlabel('No. of weeks')
plt.title('Milk Consumption per week')
plt.plot(x,y);
